# %%
from multiprocessing import Pool

import sqlite3

from play_single_game import run_and_save_chess_game
from chess_players import random_player

from IPython.core.display import display
# Out:
# /var/folders/zt/gfchqxy92bzg159q5tg9gx0h0000gn/T/ipykernel_72585/3129079367.py:8: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
# setup_sqlite() # run just once, was not idepempotent

# %%
with Pool(10) as p:
        print(p.map(run_and_save_chess_game, [random_player for i in range(98)]))
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
con = sqlite3.connect("chess_results.sql")
cur = con.cursor()
cur.execute("select * from chess_games").fetchall()
# Out:
# [(1,
#   'random_player',
#   'stockfish_0.2',
#   2,
#   'g1h3 d7d5 g2g3 e7e5 b2b4 f8b4 h3g5 d8g5 h2h3 g5d8 a2a3 b4a5 e2e4 d5e4 h1h2 b8c6 a3a4 c8e6 d1g4 e6g4 h2h1 g4f3 c1a3 c6d4 f1c4 d4c2 e1f1 c2a1 d2d3 f3h1 f2f4 d8d7 f1e2 d7h3 b1c3 h3h2 e2d1 h1f3 d1e1 h2e2'),
#  (2,
#   'random_player',
#   'stockfish_0.2',
#   2,
#   'a2a3 e7e5 g2g3 g8f6 e2e3 d7d5 f1e2 f8d6 e3e4 f6e4 g1f3 e8g8 g3g4 f7f5 a3a4 e4f2 d2d3 f2d1 c1e3 d1e3 a4a5 e3c2 e1d2 c2a1 b2b3 f5g4 b1c3 g4f3 e2f3 a1b3 d2e3 d8g5 e3f2 d6c5 d3d4 c5d4 f2f1 c8h3 f1e1 g5d2'),
#  (3,
#   'random_player',
#   'stockfish_0.2',
#   2,
#   'g1h3 d7d5 c2c3 c8h3 g2h3 e7e6 f2f3 d8h4'),
#  (4,
#   'random_player',
#   'stockfish_0.2',
#   2,
#   'g1h3 d7d5 c2c3 c8h3 g2g3 h3f1 e2e3 f1h3 d1b3 g8f6 b3d5 d8d5 h1g1 f6g4 f2f3 d5f3 e3e4 f3e4 e1d1 g4f2'),
#  (5,
#   'random_player',
#   'stockfish_0.2',
#   2,
#   'a2a4 e7e5 b2b3 d7d5 g1f3 e5e4 e2e3 e4f3 a1a2 f3g2 f1a6 g2h1q e1e2 c8g4 e2d3 g4d1 c2c4 d5c4 d3c4 h1c6'),
#  (6,
#   'random_player',
# ...
